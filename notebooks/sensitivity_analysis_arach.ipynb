# %%
import helper
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score
import random as rd

# %%
#goal simulate labeling patterns

n=100
c13ab = 0.011 #natural abundance
N = [(1-c13ab)**2,2*(1-c13ab)*c13ab,c13ab**2] #get expected labeling of precursor from natural abundance
isa_func = helper.arachidonicISA

gs = np.random.random(n)
xs = np.array([x/np.sum(x) for x in np.random.random((n,3))])
T = [0,0,1]
noiseFrac = .00

# %%
labeling_theo = []
for g,x in zip(gs,xs):
    labeling_theo.append(isa_func(g,1,x,N,None))
labeling_theo = np.array(labeling_theo)

# %%
r2_dict = {}

for noiseFrac in np.linspace(0,1,10):

    g_preds = []
    x_preds = []
    x_trues = []

    for g,x,l_true in zip(gs,xs,labeling_theo):
        tmp = l_true
        tmp = tmp / np.sum(tmp)
        noise = np.random.random(tmp.shape)
        noise = noiseFrac * noise / np.sum(noise)
        l_obs = [l+ns for l,ns in zip(tmp,noise)]
        if len(l_obs) < len(l_true): l_obs += [0 for _ in range(len(l_true)-len(l_obs))]
        l_obs = np.array(l_obs)/np.sum(l_obs)

        x_trues += list(x)
        g_pred, _, x_pred, err, l_pred = helper.ISAFit(T,N,l_obs,isa_func,list(range(len(l_obs))),.5)
        g_preds.append(g_pred)
        x_preds += list(x_pred)


    r2_dict[noiseFrac] = {}

    r2_dict[noiseFrac]["g"] = r2_score(gs,g_preds)
    r2_dict[noiseFrac]["x"] = r2_score(x_trues,x_preds)
# Out:
# C:\Users\Ethan\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:186: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   'approximations.', UserWarning)
# C:\Users\Ethan\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:186: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   'approximations.', UserWarning)
# C:\Users\Ethan\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:186: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   'approximations.', UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9306f56dbd10> in <module>
#      17
#      18         x_trues += list(x)
# ---> 19         g_pred, _, x_pred, err, l_pred = helper.ISAFit(T,N,l_obs,isa_func,list(range(len(l_obs))),.5)
#      20         g_preds.append(g_pred)
#      21         x_preds += list(x_pred)
#
# D:\imaging\helper.py in ISAFit(T, N, P, func, goodInd, x_init, plot)
#      61             lambda x: objectiveFunc(P, func(x[0], 1.0, [xx / np.sum(x[1:]) for xx in x[1:]], N, P), goodInd),
#      62             x0=initial_params,method="trust-constr",
# ---> 63             bounds=[(0, x) for x in [1,np.inf,np.inf,np.inf]])
#      64         if not sol.success:
#      65             initial_params = np.random.random(initial_params.shape)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     634         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     635                                             bounds, constraints,
# --> 636                                             callback=callback, **options)
#     637     elif meth == 'dogleg':
#     638         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_trustregion_constr\minimize_trustregion_constr.py in _minimize_trustregion_constr(fun, x0, args, grad, hess, hessp, bounds, constraints, xtol, gtol, barrier_tol, sparse_jacobian, callback, maxiter, verbose, finite_diff_rel_step, initial_constr_penalty, initial_tr_radius, initial_barrier_parameter, initial_barrier_tolerance, factorization_method, disp)
#     518             initial_barrier_tolerance,
#     519             initial_constr_penalty, initial_tr_radius,
# --> 520             factorization_method)
#     521
#     522     # Status 3 occurs when the callback function requests termination,
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_trustregion_constr\tr_interior_point.py in tr_interior_point(fun, grad, lagr_hess, n_vars, n_ineq, n_eq, constr, jac, x0, fun0, grad0, constr_ineq0, jac_ineq0, constr_eq0, jac_eq0, stop_criteria, enforce_feasibility, xtol, state, initial_barrier_parameter, initial_tolerance, initial_penalty, initial_trust_radius, factorization_method)
#     326             constr0_subprob, jac0_subprob, subprob.stop_criteria,
#     327             state, initial_penalty, trust_radius,
# --> 328             factorization_method, trust_lb, trust_ub, subprob.scaling)
#     329         if subprob.terminate:
#     330             break
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py in equality_constrained_sqp(fun_and_constr, grad_and_jac, lagr_hess, x0, fun0, grad0, constr0, jac0, stop_criteria, state, initial_penalty, initial_trust_radius, factorization_method, trust_lb, trust_ub, scaling)
#     118         dt, cg_info = projected_cg(H, c_t, Z, Y, b_t,
#     119                                    trust_radius_t,
# --> 120                                    lb_t, ub_t)
#     121
#     122         # Compute update (normal + tangential steps).
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_trustregion_constr\qp_subproblem.py in projected_cg(H, c, Z, Y, b, trust_radius, lb, ub, tol, max_iter, max_infeasible_iter, return_all)
#     497     x = Y.dot(-b)
#     498     r = Z.dot(H.dot(x) + c)
# --> 499     g = Z.dot(r)
#     500     p = -g
#     501
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\sparse\linalg\interface.py in dot(self, x)
#     416
#     417             if x.ndim == 1 or x.ndim == 2 and x.shape[1] == 1:
# --> 418                 return self.matvec(x)
#     419             elif x.ndim == 2:
#     420                 return self.matmat(x)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\sparse\linalg\interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\sparse\linalg\interface.py in _matvec(self, x)
#     528
#     529     def _matvec(self, x):
# --> 530         return self.__matvec_impl(x)
#     531
#     532     def _rmatvec(self, x):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\optimize\_trustregion_constr\projections.py in null_space(x)
#     117         # lu_sol = [ z ]
#     118         #          [aux]
# --> 119         lu_sol = solve(v)
#     120         z = lu_sol[:n]
#     121
#
# KeyboardInterrupt:

# %%
noises_test = list(r2_dict.keys())
plt.figure()
plt.plot(noises_test,[r2_dict[nt]["g"] for nt in noises_test],label="g(t)")
plt.plot(noises_test,[r2_dict[nt]["x"] for nt in noises_test],label="x")
plt.legend()
plt.xlabel("noise %")
plt.ylabel("R2")
#plt.ylim((-10,1))
#plt.savefig("simulated_data_sens_x_g.png")

# %%
print(r2_dict[0]["g"])
# Out:
# 0.8936493705088463

# %%
r2_dict = {}

for numObs in range(len(l_true)-2,len(l_true)):
    print(numObs)

    g_preds = []
    x_preds = []
    x_trues = []
    l_preds = []
    l_observed = []
    l_theo = []
    g_rels = []

    
    for g,x,l_true in zip(gs,xs,labeling_theo):
        print("going")
        iso_obs = rd.sample(list(range(len(l_true))),k=numObs)
        iso_obs.sort()
        l_obs = []
        for z in range(len(l_true)):
            if z in iso_obs:
                l_obs.append(l_true[z])
            else:
                l_obs.append(0)
        l_obs = np.array(l_obs)/np.sum(l_obs)

        g_pred, _, x_pred, err, l_pred = helper.ISAFit(T,N,l_obs,isa_func,iso_obs,.5)
        if g_pred < -.1 or g_pred > 1.1 or any(xx < -.1 or xx > 1.1 for xx in x_pred):
            g_pred = 0
            x_pred = [0,0,1]
            print("failed")
        g_rels.append(g)
        g_preds.append(g_pred)
        x_preds += list(x_pred)
        l_preds += list(l_pred)
        l_observed += list(l_obs)
        l_theo += list(l_true)
        x_trues += list(x)


    r2_dict[numObs] = {}

    r2_dict[numObs]["g"] = r2_score(g_rels,g_preds)
    r2_dict[numObs]["x"] = r2_score(x_trues,x_preds)
# Out:
# 19
# going
# going
# going
# going
# going
# going
# going
# going
# going
# going
# 20
# going
# going
# going
# going
# going
# going
# going
# going
# going
# going

# %%
noises_test = list(r2_dict.keys())
plt.figure()
plt.plot(noises_test,[r2_dict[nt]["g"] for nt in noises_test],label="g(t)")
plt.plot(noises_test,[r2_dict[nt]["x"] for nt in noises_test],label="x")
plt.legend()
plt.xlabel("# isotopologues observed")
plt.ylabel("R2")
#plt.savefig("simulated_data_sens_x_g_missing_values.png")
# Out:
# Text(0, 0.5, 'R2')

# %%
r2_dict = {}

for numObs in range(len(l_true)-2,len(l_true)):
    print(numObs)

    g_preds = []
    x_preds = []
    x_trues = []
    l_preds = []
    l_observed = []
    l_theo = []
    g_rels = []

    
    for g,x,l_true in zip(gs,xs,labeling_theo):
        print("going")
        iso_obs = rd.sample(list(range(len(l_true))),k=numObs)
        iso_obs.sort()
        l_obs = []
        for z in range(len(l_true)):
            if z in iso_obs:
                l_obs.append(l_true[z])
            else:
                l_obs.append(0)
        l_obs = np.array(l_obs)/np.sum(l_obs)

        g_pred, _, x_pred, err, l_pred = helper.ISAFit(T,N,l_obs,isa_func,iso_obs,.5)
        if g_pred < -.1 or g_pred > 1.1 or any(xx < -.1 or xx > 1.1 for xx in x_pred):
            g_pred = 0
            x_pred = [0,0,1]
            print("failed")
        g_rels.append(g)
        g_preds.append(g_pred)
        x_preds += list(x_pred)
        l_preds += list(l_pred)
        l_observed += list(l_obs)
        l_theo += list(l_true)
        x_trues += list(x)


    r2_dict[numObs] = {}

    r2_dict[numObs]["g"] = r2_score(g_rels,g_preds)
    r2_dict[numObs]["x"] = r2_score(x_trues,x_preds)
# Out:
# 19
# going
# going
# going
# going
# going
# going
# going
# going
# going
# going
# 20
# going
# going
# going
# going
# going
# going
# going
# going
# going
# going

# %%
plt.figure()
plt.scatter(gs,g_preds,color="black")
plt.plot([0,1],[0,1],color="grey")
plt.xlabel("g(t) true")
plt.ylabel("g(t) inferred")
plt.title("g(t) " + str(noiseFrac) + " R2 = " + str(np.round(r2_score(gs,g_preds),2)))

plt.figure()
plt.scatter(x_trues,x_preds,color="black")
plt.plot([0,1],[0,1],color="grey")
plt.xlabel("X true")
plt.ylabel("X inferred")
plt.title("X " + str(noiseFrac) + " R2 = " + str(np.round(r2_score(x_trues,x_preds),2)))

plt.figure()
plt.scatter(l_theo,l_preds,color="black")
plt.plot([0,1],[0,1],color="grey")
plt.xlabel("P true")
plt.ylabel("P inferred")
plt.title("P " + str(noiseFrac) + " R2 = " + str(np.round(r2_score(l_theo,l_preds),2)))


plt.figure()
plt.scatter(l_theo,l_observed,color="black")
plt.plot([0,1],[0,1],color="grey")
plt.xlabel("P true")
plt.ylabel("P observed")
plt.title("P " + str(noiseFrac) + " R2 = " + str(np.round(r2_score(l_theo,l_observed),2)))


plt.figure()
plt.scatter(l_observed,l_preds,color="black")
plt.plot([0,1],[0,1],color="grey")
plt.xlabel("P observed")
plt.ylabel("P predicted")
plt.title("P " + str(noiseFrac) + " R2 = " + str(np.round(r2_score(l_observed,l_preds),2)))
# Out:
# Text(0.5, 1.0, 'P 1.0 R2 = 1.0')

# %%
print(T,N)
# Out:
# [0, 0, 1] [0.978121, 0.021758, 0.00012099999999999999]
